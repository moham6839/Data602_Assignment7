# %% [markdown]
# # Final Project Proposal

# %% [markdown]
# ## 1. Research Question

# %% [markdown]
# Does the draft position of a NBA player affect their WinShares? How do lottery picks (1-14) affect WinShares compared with non-lottery picks? Does being a first-round pick increase or decrease WinShares? Additionally, what factors are attributable to a player having a high WinShare?

# %% [markdown]
# ## 2. Justification - why is this relevant to you or industry?

# %% [markdown]
# NBA teams that "tank" the regular season in order to get a high draft pick has been an ongoing topic of discussion. "Tanking" means purposefully not trying your best to win games in order to increase the odds of winning the NBA Draft lottery and obtaining the 1st pick in the draft. The rationale for this strategy is that players picked 1st helps the future prospects of the team's future when it comes to winning. While only 1 team can win the lottery, having a draft lottery pick that is from 2 and 14 is thought to help increase the future aspirations of teams who haven't had luck winning games. By exploring this dataset, I hope to uncover any findings that may indicate whether or not this strategy of "tanking" is worthwhile.

# %% [markdown]
# ## 3. Data Sources - did you find this data online or collect yourself? Provide links

# %% [markdown]
# I found this dataset on Kaggle:
# https://www.kaggle.com/datasets/benwieland/nba-draft-data

# %% [markdown]
# ## 4. Libraries potentially being used

# %% [markdown]
# * Pandas Library: Pandas will be used to import the csv file that contains the data and store it in a variable, as well as performing data manipulation, exploration, and cleaning.
# * NumPy Library: NumPy will be used for conducting any mathematical operation on numeric columns that can help provide any insight in why players have high WinShares. Additionally, I would like to use this library to create conditional values that can help narrow down specific players that have high WinShares.
# * Matplotlib/Seaborn Libraries: I would use one of these two libraries to visualize my findings. I'm unsure yet which library to use.

# %% [markdown]
# ## 5. EDA and summary statistics

# %% [markdown]
# When exploring the initial statistics of the data, there seems to be multiple columns that have missing data. There are two columns that have the same values (Rk and Pk), so I will drop one of them. Multiple column names are abbreviated, so for the sake of clarity I want to rename some of the columns. The mean of WinShares(WS) in the data is 17.57. There appears to be some outliers in the WS column, with the max value in WS being 248.3 and the IQR between 0.4 and 23.8. I will keep this in mind as I explore the data further.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/moham6839/Data602_Assignment7/main/draft-data-20-years.csv")

# %%
df
# Out:
#       Unnamed: 0  Rk  Pk   Tm                Player        College   Yrs  \
# 0              1   1   1  BRK       Derrick Coleman       Syracuse  15.0
# 1              2   2   2  OKC           Gary Payton   Oregon State  17.0
# 2              3   3   3  DEN    Mahmoud Abdul-Rauf            LSU   9.0
# 3              4   4   4  ORL          Dennis Scott   Georgia Tech  10.0
# 4              5   5   5  CHA          Kendall Gill       Illinois  15.0
# ...          ...  ..  ..  ...                   ...            ...   ...
# 1863        1864  56  56  CHA         Scottie Lewis        Florida   1.0
# 1864        1865  57  57  CHA       Balša Koprivica  Florida State   NaN
# 1865        1866  58  58  NYK          Jericho Sims          Texas   1.0
# 1866        1867  59  59  BRK          RaiQuan Gray  Florida State   NaN
# 1867        1868  60  60  IND  Georgios Kalaitzakis            NaN   1.0
#
#            G    TOTMP   TOTPTS  ...  WS/48  BPM  VORP  DraftYr   MPG   PPG  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0           Rk           Pk          Yrs            G  \
# count  1868.00000  1868.000000  1868.000000  1621.000000  1621.000000
# mean    934.50000    29.758030    29.758030     6.305367   342.477483
# std     539.38947    16.945052    16.945052     4.640924   322.947374
# min       1.00000     1.000000     1.000000     1.000000     1.000000
# 25%     467.75000    15.000000    15.000000     2.000000    69.000000
# 50%     934.50000    30.000000    30.000000     5.000000   230.000000
# 75%    1401.25000    44.000000    44.000000    10.000000   575.000000
# max    1868.00000    60.000000    60.000000    22.000000  1541.000000
#
#               TOTMP        TOTPTS        TOTTRB        TOTAST          FG%  \
# count   1621.000000   1621.000000   1621.000000   1621.000000  1616.000000
# mean    8250.098705   3511.962369   1477.016656    754.235657     0.435562
# std     9765.177283   4788.948725   1993.300685   1266.295204     0.084803
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1868 entries, 0 to 1867
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1868 non-null   int64
#  1   Rk          1868 non-null   int64
#  2   Pk          1868 non-null   int64
#  3   Tm          1868 non-null   object
#  4   Player      1868 non-null   object
#  5   College     1533 non-null   object
#  6   Yrs         1621 non-null   float64
#  7   G           1621 non-null   float64
#  8   TOTMP       1621 non-null   float64
#  9   TOTPTS      1621 non-null   float64
#  10  TOTTRB      1621 non-null   float64
#  11  TOTAST      1621 non-null   float64
#  12  FG%         1616 non-null   float64
#  13  3P%         1500 non-null   float64
#  14  FT%         1584 non-null   float64
#  15  WS          1621 non-null   float64
#  16  WS/48       1620 non-null   float64
#  17  BPM         1620 non-null   float64
# ...

# %%
df["WS"].mean()
# Out:
# 17.576372609500307
